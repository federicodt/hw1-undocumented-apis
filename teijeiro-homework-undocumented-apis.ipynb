# %% [markdown]
# # Homework - Finding APIs
#
# In this homework we're going to reverse-engineer [Airbnb](https://en.wikipedia.org/wiki/Airbnb)'s interactive tool to estimate the potential earnings by hosting.
#
# You can read the [press release](https://news.airbnb.com/interactive-tool-estimates-potential-monthly-host-earnings-on-airbnb/) for the tool, and view the tool on [their website](https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME).

# %% [markdown]
# ## Getting started
#
# As a reminder, you can follow along to the basic steps to do this from the [tutorial we went over during class](https://inspectelement.org/apis.html#tutorial).

# %% [markdown]
# ### 0) Go to the website, and open the developer tools.
#
# As a reminder, the website we'll be inspecting today is here:
# https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME
#
# Visit that link, and open up the developer tools (see step 1 in the tutorial).

# %% [markdown]
# ### 1) Use the site as intended
#
# With the developer tools open, go to the "Network" tab.
#
# Go back to the Airbnb website window, and search a new address. It can be any address. For example, you can check the area surrounding Columbia by entering, "Pulitzer Hall, Broadway, New York, NY, USA".
#
# We're just doing this step to trigger the network request (API call) that requests the potential earnings for the new address.

# %% [markdown]
# ### 2) Find the API call
#
# After searching a new address, you should see more entries in the "Network" tab in the developer tools.
#
# Try to find the exact API call that pulls the estimated earnings.
#
# Hint: this is steps [3 and 4](https://inspectelement.org/apis.html#filter-requests-by-fetchxhr) in the tutorial.
#
# When you feel like you found the API call, copy it as a curl, and convert that curl into a Python request using [curlconverter.com](https://curlconverter.com/).
#
# Paste the request into the cell below, and run it.

# %%
import requests

cookies = {
    'bev': '1689194696_N2FlY2M4NjExNjk4',
    'country': 'US',
    'cdn_exp_0f32753c9def38c21': 'control',
    'cdn_exp_a9d6070a0416b7ace': 'treatment',
    'cdn_exp_aff0e719002b8324c': 'control',
    'cdn_exp_c170bbabd6f357ac2': 'control',
    'cdn_exp_d878adcbec316edd5': 'control',
    'cdn_exp_75122dbaede94cfd0': 'treatment',
    'everest_cookie': '1689194696.PwynvV5x4ralI-Z8rO6a.sb1ZAu6e-NtwNwrH1UXAHplVRUfohuikMDBpb_vj5wg',
    'frmfctr': 'wide',
    '_gcl_au': '1.1.1700240456.1689194700',
    'FPID': 'FPID2.2.asR0oUPm7YWmd9mh%2B9a8iQaBCxoTP5wXWrq6ddQiqic%3D.1689194700',
    'tzo': '-180',
    'cfrmfctr': 'DESKTOP',
    'cbkp': '4',
    '_gid': 'GA1.2.1769160245.1689194701',
    '_scid': '6d76d036-22a0-4155-407a-3bc56b4a48b3',
    'OptanonConsent': '0_183215%3A1%2C0_200000%3A1%2C0_183345%3A1%2C0_183243%3A1%2C0_183216%3A1%2C0_179751%3A1%2C0_200003%3A1%2C0_200005%3A1%2C0_179754%3A1%2C0_179750%3A1%2C0_179737%3A1%2C0_179744%3A1%2C0_179739%3A1%2C0_179743%3A1%2C0_179749%3A1%2C0_200012%3A1%2C0_200011%3A1%2C0_183217%3A1%2C0_183219%3A1%2C0_183096%3A1%2C0_179747%3A1%2C0_179740%3A1%2C0_179752%3A1%2C0_183241%3A1%2C0_200007%3A1%2C0_183346%3A1%2C0_183095%3A1%2C0_210000%3A1%2C0_210001%3A1%2C0_210002%3A1',
    'sticky_locale': 'en',
    '_user_attributes': '%7B%22device_profiling_session_id%22%3A%221689194696--a7112b89df3147b15a99e01b%22%2C%22giftcard_profiling_session_id%22%3A%221689270466--8a3c34d8c28f6602013531bc%22%2C%22reservation_profiling_session_id%22%3A%221689270466--c5c85f95f95d71e66756fcf1%22%2C%22curr%22%3A%22USD%22%7D',
    'ak_bmsc': '0559EF4F4E635EF8AF8F9644FFF98B45~000000000000000000000000000000~',
    'jitney_client_session_id': 'f79e7f78-474a-4941-a868-03302aa09eed',
    'jitney_client_session_created_at': '1689270467.28',
    'AMP_TOKEN': '%24NOT_FOUND',
    'FPLC': 'Ig19GZOqQMnEvwh8pmFJPmdffJnFtIon6QWE4ygAuf4khOonni8NZDQpGvUsnEbEoPr5Gf3fTcyYO4p7WIg5HiS0GezIs58mDVge0DJTWCNm0zu53BYdKUrtjBl0xg%3D%3D',
    'jitney_client_session_updated_at': '1689270820.93',
    'OptanonAlertBoxClosed': '2023-07-13T17%3A53%3A42.441Z',
    '_ga': 'GA1.1.1024873409.1689194700',
    '_ga_2P6Q8PGG16': 'GS1.1.1689270468.3.1.1689270823.0.0.0',
    '_uetsid': 'f82bcdc020f411ee958375a9453c7ff2',
    '_uetvid': 'f82c0bf020f411ee881ec7f6f73c69cc',
    'previousTab': '%7B%22id%22%3A%227a9654de-1d73-4cb0-8cf8-61d351cf0b77%22%2C%22url%22%3A%22https%3A%2F%2Fwww.airbnb.com%2Fhost%2Fhomes%3Froom_type%3DENTIRE_HOME%22%7D',
    'bm_sv': '817B99E62E6D68A8C6199EB8E4D61190~~1',
}

headers = {
    'authority': 'www.airbnb.com',
    'accept': '*/*',
    'accept-language': 'es-AR,es;q=0.9,en-US;q=0.8,en;q=0.7,es-419;q=0.6',
    'content-type': 'application/json',
    # 'cookie': 'bev=1689194696_N2FlY2M4NjExNjk4; country=US; cdn_exp_0f32753c9def38c21=control; cdn_exp_a9d6070a0416b7ace=treatment; cdn_exp_aff0e719002b8324c=control; cdn_exp_c170bbabd6f357ac2=control; cdn_exp_d878adcbec316edd5=control; cdn_exp_75122dbaede94cfd0=treatment; everest_cookie=1689194696.PwynvV5x4ralI-Z8rO6a.sb1ZAu6e-NtwNwrH1UXAHplVRUfohuikMDBpb_vj5wg; frmfctr=wide; _gcl_au=1.1.1700240456.1689194700; FPID=FPID2.2.asR0oUPm7YWmd9mh%2B9a8iQaBCxoTP5wXWrq6ddQiqic%3D.1689194700; tzo=-180; cfrmfctr=DESKTOP; cbkp=4; _gid=GA1.2.1769160245.1689194701; _scid=6d76d036-22a0-4155-407a-3bc56b4a48b3; OptanonConsent=0_183215%3A1%2C0_200000%3A1%2C0_183345%3A1%2C0_183243%3A1%2C0_183216%3A1%2C0_179751%3A1%2C0_200003%3A1%2C0_200005%3A1%2C0_179754%3A1%2C0_179750%3A1%2C0_179737%3A1%2C0_179744%3A1%2C0_179739%3A1%2C0_179743%3A1%2C0_179749%3A1%2C0_200012%3A1%2C0_200011%3A1%2C0_183217%3A1%2C0_183219%3A1%2C0_183096%3A1%2C0_179747%3A1%2C0_179740%3A1%2C0_179752%3A1%2C0_183241%3A1%2C0_200007%3A1%2C0_183346%3A1%2C0_183095%3A1%2C0_210000%3A1%2C0_210001%3A1%2C0_210002%3A1; sticky_locale=en; _user_attributes=%7B%22device_profiling_session_id%22%3A%221689194696--a7112b89df3147b15a99e01b%22%2C%22giftcard_profiling_session_id%22%3A%221689270466--8a3c34d8c28f6602013531bc%22%2C%22reservation_profiling_session_id%22%3A%221689270466--c5c85f95f95d71e66756fcf1%22%2C%22curr%22%3A%22USD%22%7D; ak_bmsc=0559EF4F4E635EF8AF8F9644FFF98B45~000000000000000000000000000000~; jitney_client_session_id=f79e7f78-474a-4941-a868-03302aa09eed; jitney_client_session_created_at=1689270467.28; AMP_TOKEN=%24NOT_FOUND; FPLC=Ig19GZOqQMnEvwh8pmFJPmdffJnFtIon6QWE4ygAuf4khOonni8NZDQpGvUsnEbEoPr5Gf3fTcyYO4p7WIg5HiS0GezIs58mDVge0DJTWCNm0zu53BYdKUrtjBl0xg%3D%3D; jitney_client_session_updated_at=1689270820.93; OptanonAlertBoxClosed=2023-07-13T17%3A53%3A42.441Z; _ga=GA1.1.1024873409.1689194700; _ga_2P6Q8PGG16=GS1.1.1689270468.3.1.1689270823.0.0.0; _uetsid=f82bcdc020f411ee958375a9453c7ff2; _uetvid=f82c0bf020f411ee881ec7f6f73c69cc; previousTab=%7B%22id%22%3A%227a9654de-1d73-4cb0-8cf8-61d351cf0b77%22%2C%22url%22%3A%22https%3A%2F%2Fwww.airbnb.com%2Fhost%2Fhomes%3Froom_type%3DENTIRE_HOME%22%7D; bm_sv=817B99E62E6D68A8C6199EB8E4D61190~~1',
    'referer': 'https://www.airbnb.com/host/homes?room_type=ENTIRE_HOME',
    'sec-ch-ua': '"Not.A/Brand";v="8", "Chromium";v="114", "Google Chrome";v="114"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20',
    'x-airbnb-graphql-platform': 'web',
    'x-airbnb-graphql-platform-client': 'minimalist-niobe',
    'x-airbnb-supports-airlock-v2': 'true',
    'x-client-request-id': '0iciphv1uq8k6a1s1taak1eamrn7',
    'x-client-version': 'c8e1fc39b2f5e487060f1535e205aa5c629333c4',
    'x-csrf-token': 'null',
    'x-csrf-without-token': '1',
    'x-niobe-short-circuited': 'true',
}

params = {
    'operationName': 'GetHostEstimateData',
    'locale': 'en',
    'currency': 'USD',
    'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery":"1254 Amsterdam Avenue, New York, NY, USA"},"roomTypeCategory":"ENTIRE_HOME","bedroom":2,"fetchDebugInfo":false}',
    'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',
}

response = requests.get('https://www.airbnb.com/api/v3/GetHostEstimateData', params=params, cookies=cookies, headers=headers)

# %%
# use this function to show the raw JSON response
response.json()
# Out:
# {'data': {'presentation': {'__typename': 'RootPresentationContainer',
#    'hostEstimate': {'__typename': 'HostEstimatePresentationContainer',
#     'hostEstimateScreen': {'__typename': 'HostEstimateScreen',
#      'header': {'__typename': 'HostEstimateHeader',
#       'sections': [{'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText',
#          'localizedString': 'Hosts in your area earn an average of*'},
#         'suffix': {'__typename': 'I18nText', 'localizedString': '/ month'},
#         'value': '$5,225'},
#        {'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText', 'localizedString': 'They earn'},
#         'suffix': {'__typename': 'I18nText', 'localizedString': '/ night'},
#         'value': '$275'},
#        {'__typename': 'HostEstimateHeaderSection',
#         'label': {'__typename': 'I18nText',
#          'localizedString': "They're booked"},
#         'suffix': {'__typename': 'I18nText',
# ...

# %% [markdown]
# store the JSON response (dictionary) in a `records` variable to parse.

# %%
records = response.json()

# %% [markdown]
# here's a trick to see the keys in the dictionary.

# %%
records.keys()
# Out:
# dict_keys(['data', 'extensions'])

# %% [markdown]
# If the dictionary is nested, you can go to the next key, and then list the keys, again.

# %%
records['data']['presentation'].keys()
# Out:
# dict_keys(['__typename', 'hostEstimate'])

# %% [markdown]
# ### 3) Parse the response
# In the cell below, traverse the JSON response and get the estimated revenue per night. Store this in a variable named `estimate`.

# %%
records["data"]["presentation"]["hostEstimate"]["hostEstimateScreen"]["header"]["sections"][1]['value']
# Out:
# '$275'

# %%
estimate = records["data"]["presentation"]["hostEstimate"]["hostEstimateScreen"]["header"]["sections"][1]['value'] # if it isn't obvious, you should change this line of code
estimate
# Out:
# '$275'

# %% [markdown]
# ### 4) Recycle the API call
#
# Next, we're going to make the API call reusable. In the cells below fill in what the URL is for the API call

# %%
# what is the URL of the API we found?
url = 'https://www.airbnb.com/api/v3/GetHostEstimateData'

# copy the necessary headers here
headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
    'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20'}

# copy the necessary parameters here, but replace the hard-coded address with the variable
address = 'address'
params = {
    'operationName': 'GetHostEstimateData',
    'locale': 'en',
    'currency': 'USD',
    'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery":"1254 Amsterdam Avenue, New York, NY, USA"},"roomTypeCategory":"ENTIRE_HOME","bedroom":2,"fetchDebugInfo":false}',
    'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',
}

response = requests.get(url, params=params, headers=headers)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### 5) Make more API calls
# Run the API call for at least two other `address`es

# %%
import pandas as pd
import time

# %%
# here are some random addresses you can use:
addresses = [
    '217 Manhattan Avenue, New York, NY, USA',
    '65 E 96th Street, Manhattan, New York, NY, USA',
    '1809 Adam Clayton Powell Jr Boulevard, Manhattan, NY, USA'    
]

# %%
responses = []

for address in addresses:

    headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
               'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20'}
    params = {'operationName': 'GetHostEstimateData',
              'locale': 'en',
              'currency': 'USD',
              'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery": "' + address + '"},"roomTypeCategory":"ENTIRE_HOME","bedroom":2,"fetchDebugInfo":false}',
              'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',
    }

    response = requests.get(url, params=params, headers=headers)
    print(response)
    responses.append(response.json())
print("-----")
responses
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# -----
# [{'data': {'presentation': {'__typename': 'RootPresentationContainer',
#     'hostEstimate': {'__typename': 'HostEstimatePresentationContainer',
#      'hostEstimateScreen': {'__typename': 'HostEstimateScreen',
#       'header': {'__typename': 'HostEstimateHeader',
#        'sections': [{'__typename': 'HostEstimateHeaderSection',
#          'label': {'__typename': 'I18nText',
#           'localizedString': 'Hosts in your area earn an average of*'},
#          'suffix': {'__typename': 'I18nText', 'localizedString': '/ month'},
#          'value': '$4,557'},
#         {'__typename': 'HostEstimateHeaderSection',
#          'label': {'__typename': 'I18nText', 'localizedString': 'They earn'},
#          'suffix': {'__typename': 'I18nText', 'localizedString': '/ night'},
#          'value': '$217'},
#         {'__typename': 'HostEstimateHeaderSection',
#          'label': {'__typename': 'I18nText',
# ...

# %%
len(responses)
# Out:
# 3

# %%
# def search_suggestions(address):

#     headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36',
#                'x-airbnb-api-key': 'd306zoyjsyarp7ifhu67rjxn52tv0t20'}
#     params = {'operationName': 'GetHostEstimateData',
#               'locale': 'en',
#               'currency': 'USD',
#               'variables': '{"durationGranularity":["MONTHLY"],"source":"HOST_LANDING_PAGE","location":{"searchQuery": f{address},"roomTypeCategory":"ENTIRE_HOME","bedroom":2,"fetchDebugInfo":false}',
#               'extensions': '{"persistedQuery":{"version":1,"sha256Hash":"0ce03f62bd7e5cdaa639675604ea67ff782d277728c7c73b150b73c286ff9929"}}',
#     }

#     response = requests.get(url, params=params, headers=headers)
#     print(response)
#     return response.json()

# response

# %%
# responses = [] # we'll record the API responses here.
# for address in addresses:
#     suggestions = search_suggestions(address)
#     suggestions["search_address"] = address # keep track of the seed keyword
#     responses.append(response.json())
#     time.sleep(2) 
#     print(address)

# responses

# %% [markdown]
# ### 6) What are the daily estimated earnings?
# Print the estimated earning per night for each address in `responses`.

# %%
for records in responses:
    estimate = records["data"]["presentation"]["hostEstimate"]["hostEstimateScreen"]["header"]["sections"][1]['value']
    print(estimate)
# Out:
# $217
# $233
# $297

# %%
df = pd.DataFrame(responses)
df
# Out:
#                                                 data  \
# 0  {'presentation': {'__typename': 'RootPresentat...
# 1  {'presentation': {'__typename': 'RootPresentat...
# 2  {'presentation': {'__typename': 'RootPresentat...
#
#                                 extensions
# 0  {'traceId': 'Sj06GyJsZG6TOpdpoPm30A=='}
# 1  {'traceId': 'Ur-unSd5cIjEEjEb0R47AQ=='}
# 2  {'traceId': 'LwdqjCeYtW2P2HYSoDuGeg=='}

# %% [markdown]
# ### Extra Credit
# 1. We just printed the estimates above, can you also record the query addresses and print those, too?
# 2. Check different rental configurations in the number of "bedrooms".
# 3. What other information is hidden in the API response, anything interesting?
#
# ### Super Extra
# 1. Get a random sample of addresses from usps.biglocalnews.org
#     - Merge socioeconomic data from the American Community Survey
#     - Format the addresses to match the input in the Airbnb site.
# 2. Check if there are patterns in which areas are given the lowest estimates.
